# %% [markdown]
# <a href="https://colab.research.google.com/github/Thedeadji/Tugas-Magang-Infoglobal/blob/matlab/dataroket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy.io
import pandas as pd

mat_file = scipy.io.loadmat('rawdataroket.mat')
print(mat_file.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'dataarray'])

# %%
data_roket = mat_file['dataarray']

# %%
print(data_roket)
print(data_roket.shape)
# Out:
# [[ 1.00000000e+02  0.00000000e+00  5.00000000e+02 ...  6.18365401e+03
#    2.59315099e-01 -4.37708199e-03]
#  [ 1.00000000e+02  0.00000000e+00  7.50000000e+02 ...  7.41000248e+03
#    4.79371490e-01 -9.24881641e-03]
#  [ 1.00000000e+02  0.00000000e+00  1.00000000e+03 ...  8.40364880e+03
#    7.37849491e-01 -1.73478946e-03]
#  ...
#  [ 3.00000000e+02 -6.00000000e+01  1.50000000e+03 ...  8.53297097e+02
#    2.10864271e-01 -3.70111326e-02]
#  [ 3.00000000e+02 -6.00000000e+01  1.75000000e+03 ...  9.93462091e+02
#    2.89209758e-01 -9.64857172e-03]
#  [ 3.00000000e+02 -6.00000000e+01  2.00000000e+03 ...  1.13293642e+03
#    3.80998376e-01 -6.51449794e-02]]
# (385, 7)

# %%
df = pd.DataFrame(data_roket, columns=['data1', 'data2', 'data3', 'data4', 'data5', 'data6', 'data7'])
print(data_roket.shape)
# Out:
# (385, 7)

# %%
df.to_csv('data_roket.csv', index=False)
